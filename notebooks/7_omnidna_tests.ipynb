# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import AutoModelForCausalLM, AutoTokenizer
#
# File ~/new_storage/jupyter_notebooks/.venv/lib/python3.11/site-packages/transformers/__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)     36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# File ~/new_storage/jupyter_notebooks/.venv/lib/python3.11/site-packages/transformers/dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)     37     "pyyaml",
#      38 ]
#
# File ~/new_storage/jupyter_notebooks/.venv/lib/python3.11/site-packages/transformers/utils/__init__.py:19
#       1 #!/usr/bin/env python
#       2
#       3 # Copyright 2021 The HuggingFace Inc. team. All rights reserved.
#    (...)     14 # See the License for the specific language governing permissions and
#      15 # limitations under the License.
#      17 from functools import lru_cache
# ---> 19 from huggingface_hub import get_full_repo_name  # for backward compatibility
#      20 from huggingface_hub.constants import HF_HUB_DISABLE_TELEMETRY as DISABLE_TELEMETRY  # for backward compatibility
#      21 from packaging import version
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/new_storage/jupyter_notebooks/.venv/lib/python3.11/site-packages/huggingface_hub/__init__.py:1044, in _attach.<locals>.__getattr__(name)
#    1042 submod_path = f"{package_name}.{attr_to_modules[name]}"
#    1043 try:
# -> 1044     submod = importlib.import_module(submod_path)
#    1045 except Exception as e:
#    1046     print(f"Error importing {submod_path}: {e}")
#
# File /usr/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/new_storage/jupyter_notebooks/.venv/lib/python3.11/site-packages/huggingface_hub/hf_api.py:52
#      50 import requests
#      51 from requests.exceptions import HTTPError
# ---> 52 from tqdm.auto import tqdm as base_tqdm
#      53 from tqdm.contrib.concurrent import thread_map
#      55 from . import constants
#
# File ~/new_storage/jupyter_notebooks/.venv/lib/python3.11/site-packages/tqdm/__init__.py:3
#       1 from ._monitor import TMonitor, TqdmSynchronisationWarning
#       2 from ._tqdm_pandas import tqdm_pandas
# ----> 3 from .cli import main  # TODO: remove in v5.0.0
#       4 from .gui import tqdm as tqdm_gui  # TODO: remove in v5.0.0
#       5 from .gui import trange as tgrange  # TODO: remove in v5.0.0
#
# File ~/new_storage/jupyter_notebooks/.venv/lib/python3.11/site-packages/tqdm/cli.py:11
#       8 from textwrap import indent
#      10 from .std import TqdmKeyError, TqdmTypeError, tqdm
# ---> 11 from .version import __version__
#      13 __all__ = ["main"]
#      14 log = logging.getLogger(__name__)
#
# File ~/new_storage/jupyter_notebooks/.venv/lib/python3.11/site-packages/tqdm/version.py:3
#       1 """`tqdm` version detector. Precedence: installed dist, git, 'UNKNOWN'."""
#       2 try:
# ----> 3     from ._dist_ver import __version__
#       4 except ImportError:
#       5     try:
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1149, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1131, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
import os
os.environ['HF_HOME'] = '/sci/archive/michall/roeizucker/huggingface_modles_cache' 
# !export HF_HOME="/sci/archive/michall/roeizucker/huggingface_modles_cache"
# !set HF_HOME="/sci/archive/michall/roeizucker/huggingface_modles_cache"

# %%
# !pip install numpy

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# Load the model with a classification head
model = AutoModelForSequenceClassification.from_pretrained("zehui127/Omni-DNA-1B", num_labels=2, trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("zehui127/Omni-DNA-1B", trust_remote_code=True)
# Out:
# The kernel failed to start as the Python Environment 'my_new_env (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
# !pip install datasets ai2-olmo
# Out:
# Requirement already satisfied: datasets in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (4.4.2)
# Collecting ai2-olmo
#   Using cached ai2_olmo-0.6.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: filelock in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (2.3.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.7.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (0.34.4)
# Requirement already satisfied: packaging in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.10)
# Requirement already satisfied: h11>=0.16 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.1.7)
# Collecting numpy>=1.17 (from datasets)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: torch>=2.1 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from ai2-olmo) (2.7.1)
# Collecting ai2-olmo-core==0.1.0 (from ai2-olmo)
#   Using cached ai2_olmo_core-0.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: omegaconf in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from ai2-olmo) (2.3.0)
# Requirement already satisfied: rich in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from ai2-olmo) (14.1.0)
# Collecting boto3 (from ai2-olmo)
#   Using cached boto3-1.42.14-py3-none-any.whl.metadata (6.8 kB)
# Collecting google-cloud-storage (from ai2-olmo)
#   Using cached google_cloud_storage-3.7.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tokenizers in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from ai2-olmo) (0.22.1)
# Collecting cached_path>=1.6.2 (from ai2-olmo)
#   Using cached cached_path-1.8.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: transformers in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from ai2-olmo) (4.57.3)
# Collecting importlib_resources (from ai2-olmo)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: safetensors in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (0.7.0)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (2.11.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Collecting rich (from ai2-olmo)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting botocore<1.43.0,>=1.42.14 (from boto3->ai2-olmo)
#   Using cached botocore-1.42.14-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->ai2-olmo)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3->ai2-olmo)
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.14->boto3->ai2-olmo) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.14->boto3->ai2-olmo) (2.5.0)
# Collecting google-auth<3.0.0,>=2.26.1 (from google-cloud-storage->ai2-olmo)
#   Using cached google_auth-2.45.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting google-api-core<3.0.0,>=2.27.0 (from google-cloud-storage->ai2-olmo)
#   Using cached google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage->ai2-olmo)
#   Using cached google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage->ai2-olmo)
#   Using cached google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage->ai2-olmo)
#   Downloading google_crc32c-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (1.7 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo)
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo) (6.33.2)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo)
#   Using cached proto_plus-1.27.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo)
#   Using cached cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: six>=1.5 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.14->boto3->ai2-olmo) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from rich->ai2-olmo) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from rich->ai2-olmo) (2.19.2)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: mdurl~=0.1 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->ai2-olmo) (0.1.2)
# Requirement already satisfied: setuptools in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (1.14.0)
# Requirement already satisfied: networkx in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (3.5)
# Requirement already satisfied: jinja2 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.1->ai2-olmo) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from jinja2->torch>=2.1->ai2-olmo) (3.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from omegaconf->ai2-olmo) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: regex!=2019.12.17 in /cs/usr/roeizucker/new_storage/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages (from transformers->ai2-olmo) (2025.11.3)
# Using cached ai2_olmo-0.6.0-py3-none-any.whl (144.9 MB)
# Using cached ai2_olmo_core-0.1.0-py3-none-any.whl (56 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 53.3 MB/s eta 0:00:00 0:00:01
# Using cached cached_path-1.8.1-py3-none-any.whl (37 kB)
# Using cached boto3-1.42.14-py3-none-any.whl (140 kB)
# Using cached botocore-1.42.14-py3-none-any.whl (14.6 MB)
# Using cached google_cloud_storage-3.7.0-py3-none-any.whl (303 kB)
# Using cached google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Using cached google_auth-2.45.0-py2.py3-none-any.whl (233 kB)
# Using cached cachetools-6.2.4-py3-none-any.whl (11 kB)
# Using cached google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (33 kB)
# Using cached google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Using cached googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached proto_plus-1.27.0-py3-none-any.whl (50 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: pyasn1, proto-plus, numpy, jmespath, importlib_resources, googleapis-common-protos, google-crc32c, cachetools, rsa, rich, pyasn1-modules, google-resumable-media, botocore, s3transfer, google-auth, google-api-core, boto3, google-cloud-core, google-cloud-storage, cached_path, ai2-olmo-core, ai2-olmo
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/22 [proto-plus]
#     Found existing installation: numpy 2.3.2━━━━━━━━━━━━━━━━━━  1/22 [proto-plus]
#     Uninstalling numpy-2.3.2:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/22 [numpy]]
#       Successfully uninstalled numpy-2.3.2━━━━━━━━━━━━━━━━━━━━━━━━  2/22 [numpy]
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/22 [numpy]  WARNING: Failed to remove contents in a temporary directory '/sci/nosnap/michall/roeizucker/miniconda3/envs/nir_evo_env/lib/python3.12/site-packages/~umpy'.
#   You can safely remove it manually.
#   Attempting uninstall: rich91m╸━━━━━━━━━━━━━━━━━━━━━━━━━  8/22 [rsa]etools]2c]mon-protos]
#     Found existing installation: rich 14.1.0━━━━━━━━━━━━━━━━━━━━━━  9/22 [rich]
#     Uninstalling rich-14.1.0:╺━━━━━━━━━━━━━━━━━━━━━━━  9/22 [rich]
#       Successfully uninstalled rich-14.1.0━━━━━━━━━━━━━━━━━━━━  9/22 [rich]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22/22 [ai2-olmo]/22 [ai2-olmo]core]torage]a]
# Successfully installed ai2-olmo-0.6.0 ai2-olmo-core-0.1.0 boto3-1.42.14 botocore-1.42.14 cached_path-1.8.1 cachetools-6.2.4 google-api-core-2.28.1 google-auth-2.45.0 google-cloud-core-2.5.0 google-cloud-storage-3.7.0 google-crc32c-1.8.0 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 importlib_resources-6.5.2 jmespath-1.0.1 numpy-1.26.4 proto-plus-1.27.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 rich-13.9.4 rsa-4.9.1 s3transfer-0.16.0
