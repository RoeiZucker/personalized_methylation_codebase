# %%
import pandas as pd
from datasets import Dataset, DatasetDict, load_from_disk

# %%
df = pd.read_csv("/sci/archive/michall/roeizucker/Tom_project/created_datasets/Liver-Hepatocytes_Kaplan_lab.csv")

# %%
# 0.0274-0.0548
ds = load_from_disk("/sci/archive/michall/roeizucker/huggingface_datasets_dir/GSM5652237_Liver-Hepatocytes-Z0000044M_chr1_basic_test")
df = pd.read_csv("/sci/archive/michall/roeizucker/Tom_project/created_datasets/Liver-Hepatocytes_Kaplan_lab.csv")

# %%
ds
# Out:
# Dataset({
#     features: ['seq', 'labels', 'start', 'end', 'window_id', 'input_ids', 'attention_mask'],
#     num_rows: 8442
# })

# %%
df
# Out:
#           Unnamed: 0           full_position               window_id      std  \
# 0                  0        chr1:10468-10470         chr1:5400-10800  0.10535
# 1                  1        chr1:10470-10472         chr1:5400-10800  0.07760
# 2                  2        chr1:10483-10485         chr1:5400-10800  0.05460
# 3                  3        chr1:10488-10490         chr1:5400-10800  0.11940
# 4                  4        chr1:10492-10494         chr1:5400-10800  0.14090
# ...              ...                     ...                     ...      ...
# 29401355    29401355  chrY:57216281-57216283  chrY:57213000-57218400  0.00000
# 29401356    29401356  chrY:57216333-57216335  chrY:57213000-57218400  0.40820
# 29401357    29401357  chrY:57216336-57216338  chrY:57213000-57218400  0.81640
# 29401358    29401358  chrY:57216341-57216343  chrY:57213000-57218400  0.81640
# 29401359    29401359  chrY:57216439-57216441  chrY:57213000-57218400  0.00000
#
#           high_diff
# ...

# %%
file_paths = [
    "/sci/archive/michall/roeizucker/Tom_project/created_datasets/variant_data_for_analysis_1:6.csv",
    "/sci/archive/michall/roeizucker/Tom_project/created_datasets/variant_data_for_analysis_7:15.csv",
    "/sci/archive/michall/roeizucker/Tom_project/created_datasets/variant_data_for_analysis_16:Y.csv"
]

# %%
dfs = []
for path in file_paths:
    print(path)
    dfs.append(pd.read_csv(path))
# Out:
# /sci/archive/michall/roeizucker/Tom_project/created_datasets/variant_data_for_analysis_1:6.csv
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 4
#       2 for path in file_paths:
#       3     print(path)
# ----> 4     dfs.append(pd.read_csv(path))
#
# ...
